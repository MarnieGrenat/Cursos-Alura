# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados= pd.read_csv('aluguel_residencial.csv', sep=';')

# %%
dados.head(4)
# Out:
#    Unnamed: 0         Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0           0    Quitinete       Copacabana        1      0       0    40
# 1           1         Casa  Jardim Botânico        2      0       1   100
# 2           2  Apartamento           Centro        1      0       0    15
# 3           3  Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio  IPTU
# 0  1700.0       500.0  60.0
# 1  7000.0         0.0   0.0
# 2   800.0       390.0  20.0
# 3   800.0       230.0   0.0

# %%
#bairros= ['Barra da Tijuca', 'Copacabana','Ipanema','Leblon','Botafogo','Tijuca']
#new_data=dados[dados['Bairro'].isin(bairros)]

# %%
grupo_bairros= dados.groupby('Bairro')
#type(grupo_bairros)

# %%
#grupo_bairros.groups

# %%
for bairro, data in grupo_bairros:
    print('Bairro: ', bairro)
    print('Média: ', data.Valor.mean().round(4))
    print()
    #print(dados)
# Out:
# Bairro:  Abolição
# Média:  1195.3333
#
# Bairro:  Alto da Boa Vista
# Média:  3966.6667
#
# Bairro:  Anchieta
# Média:  875.0
#
# Bairro:  Andaraí
# Média:  1464.7113
#
# Bairro:  Anil
# Média:  2048.8732
#
# Bairro:  Arpoador
# Média:  12923.9167
#
# Bairro:  Bancários
# Média:  1825.0
#
# Bairro:  Bangu
# Média:  1016.0
#
# Bairro:  Barra da Tijuca
# Média:  7069.5529
#
# Bairro:  Barra de Guaratiba
# Média:  5550.0
#
# Bairro:  Benfica
# Média:  996.0
#
# Bairro:  Bento Ribeiro
# Média:  1030.8696
#
# Bairro:  Bonsucesso
# Média:  1225.9322
#
# Bairro:  Botafogo
# Média:  8791.8282
#
# Bairro:  Braz de Pina
# Média:  1115.0
#
# Bairro:  Cachambi
# Média:  1157.1742
#
# Bairro:  Cachamorra
# Média:  3000.0
#
# Bairro:  Cacuia
# Média:  916.6667
#
# Bairro:  Caju
# Média:  850.0
#
# Bairro:  Camorim
# Média:  1735.2273
#
# Bairro:  Campinho
# Média:  1037.3333
#
# Bairro:  Campo Grande
# Média:  1267.7171
#
# Bairro:  Cascadura
# Média:  948.7097
#
# Bairro:  Catete
# Média:  2267.0625
#
# Bairro:  Catumbi
# Média:  1112.5
#
# Bairro:  Cavalcanti
# Média:  595.0
#
# Bairro:  Centro
# Média:  1254.7522
#
# Bairro:  Cidade Jardim
# Média:  12000.0
#
# Bairro:  Cidade Nova
# Média:  1471.4286
#
# Bairro:  Cocotá
# Média:  1883.3333
#
# Bairro:  Coelho Neto
# Média:  700.0
#
# Bairro:  Colégio
# Média:  885.0
#
# Bairro:  Copacabana
# Média:  4126.677
#
# Bairro:  Cordovil
# Média:  905.5556
#
# Bairro:  Cosme Velho
# Média:  5343.5484
#
# Bairro:  Cosmos
# Média:  658.3333
#
# Bairro:  Curicica
# Média:  1514.5658
#
# Bairro:  Del Castilho
# Média:  1261.3043
#
# Bairro:  Encantado
# Média:  1050.0
#
# Bairro:  Engenho Novo
# Média:  1035.8252
#
# Bairro:  Engenho da Rainha
# Média:  883.5714
#
# Bairro:  Engenho de Dentro
# Média:  1166.3514
#
# Bairro:  Estácio
# Média:  1233.913
#
# Bairro:  Flamengo
# Média:  4113.5266
#
# Bairro:  Freguesia (Ilha do Governador)
# Média:  1720.0
#
# Bairro:  Freguesia (Jacarepaguá)
# Média:  4966.6667
#
# Bairro:  Fátima
# Média:  956.6667
#
# Bairro:  Gamboa
# Média:  1116.6667
#
# Bairro:  Gardênia Azul
# Média:  761.1111
#
# Bairro:  Glória
# Média:  2467.2897
#
# Bairro:  Grajaú
# Média:  2038.6207
#
# Bairro:  Guadalupe
# Média:  700.0
#
# Bairro:  Guaratiba
# Média:  1232.2581
#
# Bairro:  Gávea
# Média:  6563.6884
#
# Bairro:  Higienópolis
# Média:  1006.25
#
# Bairro:  Honório Gurgel
# Média:  628.5714
#
# Bairro:  Humaitá
# Média:  3802.3101
#
# Bairro:  Icaraí
# Média:  2393.75
#
# Bairro:  Ilha do Governador
# Média:  1728.0
#
# Bairro:  Inhaúma
# Média:  821.4286
#
# Bairro:  Inhoaíba
# Média:  725.0
#
# Bairro:  Ipanema
# Média:  9352.0011
#
# Bairro:  Irajá
# Média:  1096.0127
#
# Bairro:  Itanhangá
# Média:  9341.2698
#
# Bairro:  Jabour
# Média:  723.3333
#
# Bairro:  Jacarepaguá
# Média:  2046.9878
#
# Bairro:  Jacaré
# Média:  1200.0
#
# Bairro:  Jardim América
# Média:  714.2857
#
# Bairro:  Jardim Botânico
# Média:  8722.3574
#
# Bairro:  Jardim Carioca
# Média:  2211.1111
#
# Bairro:  Jardim Guanabara
# Média:  2124.6875
#
# Bairro:  Jardim Oceânico
# Média:  7626.087
#
# Bairro:  Jardim Sulacap
# Média:  1176.6667
#
# Bairro:  Joá
# Média:  16773.4783
#
# Bairro:  Lagoa
# Média:  8147.0758
#
# Bairro:  Lapa
# Média:  1488.7778
#
# Bairro:  Laranjeiras
# Média:  3555.2776
#
# Bairro:  Largo do Machado
# Média:  1880.0
#
# Bairro:  Leblon
# Média:  8746.345
#
# Bairro:  Leme
# Média:  3944.7598
#
# Bairro:  Lins de Vasconcelos
# Média:  1086.1702
#
# Bairro:  Madureira
# Média:  1017.6596
#
# Bairro:  Magalhães Bastos
# Média:  640.0
#
# Bairro:  Maracanã
# Média:  1945.4961
#
# Bairro:  Marechal Hermes
# Média:  844.4444
#
# Bairro:  Maria da Graça
# Média:  1073.3333
#
# Bairro:  Moneró
# Média:  1900.0
#
# Bairro:  Méier
# Média:  1355.8745
#
# Bairro:  Olaria
# Média:  1016.5625
#
# Bairro:  Oswaldo Cruz
# Média:  823.8889
#
# Bairro:  Paciência
# Média:  580.0
#
# Bairro:  Padre Miguel
# Média:  786.25
#
# Bairro:  Paquetá
# Média:  10550.0
#
# Bairro:  Parada de Lucas
# Média:  1062.5
#
# Bairro:  Parque Anchieta
# Média:  1287.5
#
# Bairro:  Pavuna
# Média:  648.9474
#
# Bairro:  Pechincha
# Média:  1357.4257
#
# Bairro:  Pedra de Guaratiba
# Média:  1082.1053
#
# Bairro:  Penha
# Média:  1023.3333
#
# Bairro:  Penha Circular
# Média:  1160.0
#
# Bairro:  Península
# Média:  7061.5385
#
# Bairro:  Piedade
# Média:  956.5385
#
# Bairro:  Pilares
# Média:  1077.5
#
# Bairro:  Pitangueiras
# Média:  2725.0
#
# Bairro:  Portuguesa
# Média:  1272.7273
#
# Bairro:  Praia da Bandeira
# Média:  1300.0
#
# Bairro:  Praça Seca
# Média:  998.4146
#
# Bairro:  Praça da Bandeira
# Média:  1358.7234
#
# Bairro:  Quintino Bocaiúva
# Média:  924.6667
#
# Bairro:  Ramos
# Média:  958.0
#
# Bairro:  Realengo
# Média:  908.3333
#
# Bairro:  Recreio dos Bandeirantes
# Média:  3736.6131
#
# Bairro:  Riachuelo
# Média:  1143.9024
#
# Bairro:  Ribeira
# Média:  1420.0
#
# Bairro:  Rio Comprido
# Média:  1610.2405
#
# Bairro:  Rio da Prata
# Média:  1300.0
#
# Bairro:  Rocha
# Média:  1086.8421
#
# Bairro:  Rocha Miranda
# Média:  877.0
#
# Bairro:  Sampaio
# Média:  937.5
#
# Bairro:  Santa Cruz
# Média:  734.2857
#
# Bairro:  Santa Teresa
# Média:  2713.3333
#
# Bairro:  Santo Cristo
# Média:  1225.0
#
# Bairro:  Santíssimo
# Média:  756.25
#
# Bairro:  Saúde
# Média:  950.0
#
# Bairro:  Senador Camará
# Média:  600.0
#
# Bairro:  Senador Vasconcelos
# Média:  867.3529
#
# Bairro:  São Conrado
# Média:  8780.888
#
# Bairro:  São Cristóvão
# Média:  1391.7188
#
# Bairro:  São Francisco Xavier
# Média:  1237.2414
#
# Bairro:  Tanque
# Média:  1335.7143
#
# Bairro:  Taquara
# Média:  1642.1404
#
# Bairro:  Tauá
# Média:  1340.0
#
# Bairro:  Tijuca
# Média:  2043.52
#
# Bairro:  Todos os Santos
# Média:  1243.0769
#
# Bairro:  Tomás Coelho
# Média:  737.0
#
# Bairro:  Turiaçu
# Média:  700.0
#
# Bairro:  Urca
# Média:  7925.9589
#
# Bairro:  Usina
# Média:  1520.0
#
# Bairro:  Vargem Grande
# Média:  3358.1667
#
# Bairro:  Vargem Pequena
# Média:  2703.4808
#
# Bairro:  Vaz Lobo
# Média:  845.0
#
# Bairro:  Vicente de Carvalho
# Média:  1075.7143
#
# Bairro:  Vidigal
# Média:  2600.0
#
# Bairro:  Vigário Geral
# Média:  970.0
#
# Bairro:  Vila Isabel
# Média:  1560.8333
#
# Bairro:  Vila Kosmos
# Média:  1311.8182
#
# Bairro:  Vila Militar
# Média:  500.0
#
# Bairro:  Vila Valqueire
# Média:  1769.5833
#
# Bairro:  Vila da Penha
# Média:  1260.5769
#
# Bairro:  Vista Alegre
# Média:  1114.375
#
# Bairro:  Zumbi
# Média:  2150.0
#
# Bairro:  Água Santa
# Média:  861.1111

# %%
grupo_bairros[['Valor']].mean().round(4)
# Out:
#                            Valor
# Bairro
# Abolição               1195.3333
# Alto da Boa Vista      3966.6667
# Anchieta                875.0000
# Andaraí                1464.7113
# Anil                   2048.8732
# Arpoador              12923.9167
# Bancários              1825.0000
# Bangu                  1016.0000
# Barra da Tijuca        7069.5529
# Barra de Guaratiba     5550.0000
# Benfica                 996.0000
# Bento Ribeiro          1030.8696
# Bonsucesso             1225.9322
# Botafogo               8791.8282
# Braz de Pina           1115.0000
# Cachambi               1157.1742
# Cachamorra             3000.0000
# Cacuia                  916.6667
# Caju                    850.0000
# Camorim                1735.2273
# Campinho               1037.3333
# Campo Grande           1267.7171
# Cascadura               948.7097
# Catete                 2267.0625
# Catumbi                1112.5000
# Cavalcanti              595.0000
# Centro                 1254.7522
# Cidade Jardim         12000.0000
# Cidade Nova            1471.4286
# Cocotá                 1883.3333
# ...                          ...
# Santíssimo              756.2500
# Saúde                   950.0000
# Senador Camará          600.0000
# Senador Vasconcelos     867.3529
# São Conrado            8780.8880
# São Cristóvão          1391.7188
# São Francisco Xavier   1237.2414
# Tanque                 1335.7143
# Taquara                1642.1404
# Tauá                   1340.0000
# Tijuca                 2043.5200
# Todos os Santos        1243.0769
# Tomás Coelho            737.0000
# Turiaçu                 700.0000
# Urca                   7925.9589
# Usina                  1520.0000
# Vargem Grande          3358.1667
# Vargem Pequena         2703.4808
# Vaz Lobo                845.0000
# Vicente de Carvalho    1075.7143
# Vidigal                2600.0000
# Vigário Geral           970.0000
# Vila Isabel            1560.8333
# Vila Kosmos            1311.8182
# Vila Militar            500.0000
# Vila Valqueire         1769.5833
# Vila da Penha          1260.5769
# Vista Alegre           1114.3750
# Zumbi                  2150.0000
# Água Santa              861.1111
#
# [152 rows x 1 columns]

# %% [markdown]
# # Estatística Descritivas

# %%
grupo_bairros['Valor'].describe(\[
    
]).round(2)
# Out:
#                        count      mean        std      min      25%      50%  \
# Bairro
# Abolição                15.0   1195.33     425.32    800.0    900.0   1180.0
# Alto da Boa Vista        6.0   3966.67    5513.59    600.0   1150.0   1725.0
# Anchieta                 4.0    875.00     132.29    700.0    812.5    900.0
# Andaraí                 97.0   1464.71     408.11    700.0   1200.0   1400.0
# Anil                    71.0   2048.87    1523.97    300.0   1100.0   1500.0
# Arpoador                12.0  12923.92    9064.21   4200.0   7325.0   8600.0
# Bancários                4.0   1825.00     665.21   1300.0   1525.0   1600.0
# Bangu                   20.0   1016.00     347.24    400.0    825.0    950.0
# Barra da Tijuca       3863.0   7069.55   11874.15    800.0   2500.0   4500.0
# Barra de Guaratiba       4.0   5550.00    2716.00   2200.0   3925.0   6000.0
# Benfica                  5.0    996.00     205.01    790.0    790.0   1000.0
# Bento Ribeiro           23.0   1030.87     465.33    480.0    700.0    900.0
# Bonsucesso              59.0   1225.93     617.23    600.0    925.0   1100.0
# Botafogo               873.0   8791.83  152202.41    700.0   2200.0   3000.0
# Braz de Pina            20.0   1115.00     507.79    450.0    800.0    945.0
# Cachambi               132.0   1157.17     351.49    600.0    900.0   1100.0
# Cachamorra               1.0   3000.00        NaN   3000.0   3000.0   3000.0
# Cacuia                   3.0    916.67     125.83    800.0    850.0    900.0
# Caju                     1.0    850.00        NaN    850.0    850.0    850.0
# Camorim                 44.0   1735.23    1064.03    800.0   1175.0   1500.0
# Campinho                15.0   1037.33     367.88    650.0    750.0    850.0
# Campo Grande           449.0   1267.72    1297.52    400.0    750.0   1000.0
# Cascadura               31.0    948.71     238.53    650.0    755.0    850.0
# Catete                 160.0   2267.06    2210.61    700.0   1200.0   1800.0
# Catumbi                  8.0   1112.50     248.93    650.0    975.0   1175.0
# Cavalcanti               2.0    595.00       7.07    590.0    592.5    595.0
# Centro                 343.0   1254.75     884.67    400.0    800.0   1000.0
# Cidade Jardim            1.0  12000.00        NaN  12000.0  12000.0  12000.0
# Cidade Nova              7.0   1471.43     468.03    800.0   1250.0   1300.0
# Cocotá                   3.0   1883.33    1837.34    700.0    825.0    950.0
# ...                      ...       ...        ...      ...      ...      ...
# Santíssimo               8.0    756.25      82.10    650.0    700.0    750.0
# Saúde                    2.0    950.00     494.97    600.0    775.0    950.0
# Senador Camará           1.0    600.00        NaN    600.0    600.0    600.0
# Senador Vasconcelos     17.0    867.35     439.35    500.0    650.0    800.0
# São Conrado            259.0   8780.89    7156.52   1400.0   3500.0   6000.0
# São Cristóvão           64.0   1391.72     437.67    530.0   1087.5   1300.0
# São Francisco Xavier    29.0   1237.24     309.79    700.0   1000.0   1200.0
# Tanque                  28.0   1335.71     463.85    600.0   1100.0   1250.0
# Taquara                171.0   1642.14    1469.74    500.0    900.0   1100.0
# Tauá                     8.0   1340.00     355.49    870.0   1112.5   1350.0
# Tijuca                1100.0   2043.52    1664.34    750.0   1500.0   1800.0
# Todos os Santos         52.0   1243.08     236.81    800.0   1075.0   1300.0
# Tomás Coelho            10.0    737.00      80.97    650.0    670.0    725.0
# Turiaçu                  5.0    700.00     117.26    600.0    650.0    650.0
# Urca                    73.0   7925.96    7317.02   1200.0   3000.0   4900.0
# Usina                    5.0   1520.00     319.37   1100.0   1300.0   1600.0
# Vargem Grande           60.0   3358.17    3200.17    800.0   1675.0   2125.0
# Vargem Pequena          52.0   2703.48    2555.56    850.0   1200.0   1850.0
# Vaz Lobo                26.0    845.00     274.43    400.0    612.5    800.0
# Vicente de Carvalho     14.0   1075.71     525.09    500.0    762.5   1000.0
# Vidigal                  4.0   2600.00    1467.42   1300.0   1525.0   2300.0
# Vigário Geral            5.0    970.00     408.66    550.0    700.0    800.0
# Vila Isabel            300.0   1560.83     479.07    700.0   1250.0   1500.0
# Vila Kosmos             11.0   1311.82     448.59    850.0   1000.0   1250.0
# Vila Militar             2.0    500.00       0.00    500.0    500.0    500.0
# Vila Valqueire          48.0   1769.58    2203.01    800.0   1000.0   1250.0
# Vila da Penha          104.0   1260.58     644.66    450.0    900.0   1100.0
# Vista Alegre            16.0   1114.38     199.60    700.0   1012.5   1200.0
# Zumbi                    2.0   2150.00     777.82   1600.0   1875.0   2150.0
# Água Santa               9.0    861.11     174.60    600.0    800.0    850.0
#
#                            75%        max
# Bairro
# Abolição               1200.00     2300.0
# Alto da Boa Vista      3275.00    15000.0
# Anchieta                962.50     1000.0
# Andaraí                1650.00     2950.0
# Anil                   2675.00     7000.0
# Arpoador              16221.75    30000.0
# Bancários              1900.00     2800.0
# Bangu                  1187.50     1650.0
# Barra da Tijuca        8500.00   600000.0
# Barra de Guaratiba     7625.00     8000.0
# Benfica                1200.00     1200.0
# Bento Ribeiro          1350.00     2200.0
# Bonsucesso             1350.00     4500.0
# Botafogo               4350.00  4500000.0
# Braz de Pina           1300.00     2300.0
# Cachambi               1300.00     2800.0
# Cachamorra             3000.00     3000.0
# Cacuia                  975.00     1050.0
# Caju                    850.00      850.0
# Camorim                1700.00     6000.0
# Campinho               1350.00     1700.0
# Campo Grande           1400.00    12000.0
# Cascadura              1200.00     1500.0
# Catete                 2400.00    15000.0
# Catumbi                1300.00     1400.0
# Cavalcanti              597.50      600.0
# Centro                 1400.00    12000.0
# Cidade Jardim         12000.00    12000.0
# Cidade Nova            1750.00     2200.0
# Cocotá                 2475.00     4000.0
# ...                        ...        ...
# Santíssimo              800.00      900.0
# Saúde                  1125.00     1300.0
# Senador Camará          600.00      600.0
# Senador Vasconcelos     850.00     2495.0
# São Conrado           11749.50    45000.0
# São Cristóvão          1625.00     2500.0
# São Francisco Xavier   1400.00     2000.0
# Tanque                 1500.00     2500.0
# Taquara                1800.00    10000.0
# Tauá                   1450.00     2000.0
# Tijuca                 2300.00    45000.0
# Todos os Santos        1412.50     1800.0
# Tomás Coelho            790.00      900.0
# Turiaçu                 700.00      900.0
# Urca                  10000.00    35000.0
# Usina                  1700.00     1900.0
# Vargem Grande          4000.00    20000.0
# Vargem Pequena         3412.50    17000.0
# Vaz Lobo                997.50     1500.0
# Vicente de Carvalho    1175.00     2500.0
# Vidigal                3375.00     4500.0
# Vigário Geral          1300.00     1500.0
# Vila Isabel            1700.00     4500.0
# Vila Kosmos            1515.00     2300.0
# Vila Militar            500.00      500.0
# Vila Valqueire         1700.00    16000.0
# Vila da Penha          1302.50     4500.0
# Vista Alegre           1225.00     1400.0
# Zumbi                  2425.00     2700.0
# Água Santa              950.00     1200.0
#
# [152 rows x 8 columns]

# %%
new_data= grupo_bairros['Valor'].aggregate(['min', 'max']).rename(columns={'min':'Mínimo','max':'Máximo'})

# %%
# %matplotlib inline
import matplotlib as plt
plt.rc('figure', figsize=(20,10))

# %%
fig= grupo_bairros['Valor'].std().plot.bar(color='blue')
